# %%
#Import modules
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# Importing csv file 
url = 'https://raw.githubusercontent.com/umaimehm/Intro_to_AI_2021/main/assignment1/Ruter_data.csv'

# %%
df = pd.read_csv(url, sep=';')

df.head(10)
# Out:
#                              TurId        Dato  Fylke    Område  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken      Vest
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken      Vest
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken      Vest
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken      Vest
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken      Vest
# 5   3110-2020-08-01T16:16:00+02:00  01/08/2020   Oslo   Nordøst
# 6  15010-2020-07-28T13:09:00+02:00  28/07/2020  Viken      Vest
# 7  15003-2020-07-27T06:18:00+02:00  27/07/2020   Oslo  Indre By
# 8  21002-2020-08-16T14:33:00+02:00  16/08/2020  Viken      Vest
# 9  15002-2020-08-13T18:09:00+02:00  13/08/2020  Viken      Vest
#
#          Kommune                               Holdeplass_Fra  \
# 0          Bærum                                  Nordliveien
# 1          Bærum                             Nadderud stadion
# 2          Bærum                             Ringstabekkveien
# 3          Bærum                                    Gruvemyra
# 4          Bærum                Lysaker stasjon (Plattform A)
# 5         Bjerke                     Veitvet  (mot Kalbakken)
# 6          Bærum                             Nedre Toppenhaug
# 7  St.Hanshaugen  Hammersborggata (ved Storgata retning vest)
# 8          Bærum                                   Stein gård
# 9          Bærum         Bekkestua bussterminal (Plattform C)
#
#                           Holdeplass_Til Linjetype Linjefylke Linjenavn  \
# 0                              Tjernsmyr     Lokal      Viken       150
# 1   Bekkestua bussterminal (Plattform C)     Lokal      Viken       150
# 2                                Skallum     Lokal      Viken       150
# 3                               Gullhaug     Lokal      Viken       150
# 4                              Tjernsmyr     Lokal      Viken       150
# 5               Rødtvet  (mot Kalbakken)     Lokal       Oslo        31
# 6                        Øvre Toppenhaug     Lokal      Viken       150
# 7  St. Olavs plass  (mot Frederiks gate)     Lokal      Viken       150
# 8                         Knabberudveien     Lokal      Viken       150
# 9                          Stabekk skole     Lokal      Viken       150
#
#    Linjeretning Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0             0                                 10:53:53
# 1             0                                 13:12:20
# 2             0                                 10:18:56
# 3             1                                 13:52:04
# 4             1                                 07:34:13
# 5             0                                 17:22:56
# 6             0                                 13:19:00
# 7             1                                 06:20:24
# 8             1                                 15:10:12
# 9             0                                 18:37:41
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                10:53:59
# 1                                13:12:26
# 2                                10:19:21
# 3                                13:52:26
# 4                                07:34:53
# 5                                17:23:23
# 6                                13:19:05
# 7                                06:20:29
# 8                                15:10:34
# 9                                18:38:19
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:00
# 1                                  13:12:00
# 2                                  10:19:00
# 3                                  13:51:00
# 4                                  07:33:00
# 5                                  17:16:00
# 6                                  13:17:00
# 7                                  06:20:00
# 8                                  15:09:00
# 9                                  18:29:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                                 10:53:00                 112
# 1                                 13:12:00                 112
# 2                                 10:19:00                 112
# 3                                 13:51:00                 112
# 4                                 07:33:00                 112
# 5                                 17:16:00                 151
# 6                                 13:17:00                 112
# 7                                 06:20:00                 112
# 8                                 15:09:00                 112
# 9                                 18:29:00                 112
#
#    Passasjerer_Ombord
# 0                   5
# 1                   5
# 2                   6
# 3                  10
# 4                  10
# 5                   8
# 6                   1
# 7                  -1
# 8                   2
# 9                   4

# %% [markdown]
# Some values in "Passasjer_Ombord" is negative. It is informed in the assignment that this might be due to sensors not working properly, so we choose to change these values to zero.

# %%
df["Passasjerer_Ombord"] = np.where(df["Passasjerer_Ombord"] < 0, 0, df["Passasjerer_Ombord"])

# %%
df.head(10)
# Out:
#                              TurId        Dato  Fylke    Område  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken      Vest
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken      Vest
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken      Vest
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken      Vest
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken      Vest
# 5   3110-2020-08-01T16:16:00+02:00  01/08/2020   Oslo   Nordøst
# 6  15010-2020-07-28T13:09:00+02:00  28/07/2020  Viken      Vest
# 7  15003-2020-07-27T06:18:00+02:00  27/07/2020   Oslo  Indre By
# 8  21002-2020-08-16T14:33:00+02:00  16/08/2020  Viken      Vest
# 9  15002-2020-08-13T18:09:00+02:00  13/08/2020  Viken      Vest
#
#          Kommune                               Holdeplass_Fra  \
# 0          Bærum                                  Nordliveien
# 1          Bærum                             Nadderud stadion
# 2          Bærum                             Ringstabekkveien
# 3          Bærum                                    Gruvemyra
# 4          Bærum                Lysaker stasjon (Plattform A)
# 5         Bjerke                     Veitvet  (mot Kalbakken)
# 6          Bærum                             Nedre Toppenhaug
# 7  St.Hanshaugen  Hammersborggata (ved Storgata retning vest)
# 8          Bærum                                   Stein gård
# 9          Bærum         Bekkestua bussterminal (Plattform C)
#
#                           Holdeplass_Til Linjetype Linjefylke Linjenavn  \
# 0                              Tjernsmyr     Lokal      Viken       150
# 1   Bekkestua bussterminal (Plattform C)     Lokal      Viken       150
# 2                                Skallum     Lokal      Viken       150
# 3                               Gullhaug     Lokal      Viken       150
# 4                              Tjernsmyr     Lokal      Viken       150
# 5               Rødtvet  (mot Kalbakken)     Lokal       Oslo        31
# 6                        Øvre Toppenhaug     Lokal      Viken       150
# 7  St. Olavs plass  (mot Frederiks gate)     Lokal      Viken       150
# 8                         Knabberudveien     Lokal      Viken       150
# 9                          Stabekk skole     Lokal      Viken       150
#
#    Linjeretning Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0             0                                 10:53:53
# 1             0                                 13:12:20
# 2             0                                 10:18:56
# 3             1                                 13:52:04
# 4             1                                 07:34:13
# 5             0                                 17:22:56
# 6             0                                 13:19:00
# 7             1                                 06:20:24
# 8             1                                 15:10:12
# 9             0                                 18:37:41
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                10:53:59
# 1                                13:12:26
# 2                                10:19:21
# 3                                13:52:26
# 4                                07:34:53
# 5                                17:23:23
# 6                                13:19:05
# 7                                06:20:29
# 8                                15:10:34
# 9                                18:38:19
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:00
# 1                                  13:12:00
# 2                                  10:19:00
# 3                                  13:51:00
# 4                                  07:33:00
# 5                                  17:16:00
# 6                                  13:17:00
# 7                                  06:20:00
# 8                                  15:09:00
# 9                                  18:29:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                                 10:53:00                 112
# 1                                 13:12:00                 112
# 2                                 10:19:00                 112
# 3                                 13:51:00                 112
# 4                                 07:33:00                 112
# 5                                 17:16:00                 151
# 6                                 13:17:00                 112
# 7                                 06:20:00                 112
# 8                                 15:09:00                 112
# 9                                 18:29:00                 112
#
#    Passasjerer_Ombord
# 0                   5
# 1                   5
# 2                   6
# 3                  10
# 4                  10
# 5                   8
# 6                   1
# 7                   0
# 8                   2
# 9                   4

# %% [markdown]
# # Features that have chosen to add are:
# # 1. "Forsinkelsestid"
# # 2. "Er_Forsinket"
# # 3. "Ukedag"
# # 4. "Måned"
# # 5. "PlassPåBussen"
#
# In each describtion of the features you are able to see a display of how the table looks after the changes that have been made. Presentation of plots and statistics may also occur within these.

# %% [markdown]
# # 1. "Forsinkelsestid" - what was the time delay

# %% [markdown]
# The values in the columns that show departure and arrival are being converted to datetime, so that we can subtract to find the specific total delay time.

# %%
df['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'] = pd.to_datetime(df['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'], errors='coerce')
df['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] = pd.to_datetime(df['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'], errors='coerce')
df['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra'] = pd.to_datetime(df['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra'], errors='coerce')
df['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra'] = pd.to_datetime(df['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra'], errors='coerce')

# %%
df['Forsinkelsestid'] = df['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] - df['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra']

# %%
df.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# 1     Lokal      Viken       150             0
# 2     Lokal      Viken       150             0
# 3     Lokal      Viken       150             1
# 4     Lokal      Viken       150             1
#
#   Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                      2021-09-27 10:53:53
# 1                      2021-09-27 13:12:20
# 2                      2021-09-27 10:18:56
# 3                      2021-09-27 13:52:04
# 4                      2021-09-27 07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                     2021-09-27 10:53:59
# 1                     2021-09-27 13:12:26
# 2                     2021-09-27 10:19:21
# 3                     2021-09-27 13:52:26
# 4                     2021-09-27 07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                       2021-09-27 10:53:00
# 1                       2021-09-27 13:12:00
# 2                       2021-09-27 10:19:00
# 3                       2021-09-27 13:51:00
# 4                       2021-09-27 07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                      2021-09-27 10:53:00                 112
# 1                      2021-09-27 13:12:00                 112
# 2                      2021-09-27 10:19:00                 112
# 3                      2021-09-27 13:51:00                 112
# 4                      2021-09-27 07:33:00                 112
#
#    Passasjerer_Ombord Forsinkelsestid
# 0                   5 0 days 00:00:59
# 1                   5 0 days 00:00:26
# 2                   6 0 days 00:00:21
# 3                  10 0 days 00:01:26
# 4                  10 0 days 00:01:53

# %% [markdown]
# # 2. "Er forsinket" - Categorizing lateness
# This is connected to 1. "Forsinkelsestid".

# %% [markdown]
# It can be useful to see how often a bus leaves the platform early, late or on time.
# We will categorize Forsinkelsestid into five numerical values.

# %%
df["Forsinkelsestid"].describe()
# Out:
# count                         5823
# mean     0 days 00:01:59.495964279
# std      0 days 00:09:15.871448203
# min              -1 days +14:39:34
# 25%                0 days 00:00:50
# 50%                0 days 00:01:43
# 75%                0 days 00:03:00
# max                0 days 02:33:33
# Name: Forsinkelsestid, dtype: object

# %% [markdown]
# We'll give the bus a four-minute time slot where it is considered on time.
# So if the bus leaves two minutes before the planned departure time, or two minutes after, the bus is considered too early or late.
# We can categorize the early and lateness into categories of lateness.
# 0 is ten or more minutes early, 1 is more than two minutes early, 2 is on time; two minutes before and after est departure time, 3 is under ten minutes late, and 4 is ten minutes late or more.

# %%
conditions = [
    (df['Forsinkelsestid'] <= "-1 days +23:50:00"),
    (df['Forsinkelsestid'] > "-1 days +23:50:00") & (df['Forsinkelsestid'] <= "-1 days +23:58:00"),
    (df['Forsinkelsestid'] > "-1 days +23:58:00") & (df['Forsinkelsestid'] <= "0 days 00:02:00"),
    (df['Forsinkelsestid'] > "0 days 00:02:00") & (df['Forsinkelsestid'] <= "0 days 00:10:00"),
    (df['Forsinkelsestid'] > "0 days 00:10:00")
    ]

values = [0, 1, 2, 3, 4]

df['cat_Forsinkelse'] = np.select(conditions, values)

# %%
df_lateCount = df.groupby('cat_Forsinkelse').count()
df_lateCount.Forsinkelsestid
# Out:
# cat_Forsinkelse
# 0      87
# 1     100
# 2    3112
# 3    2384
# 4     140
# Name: Forsinkelsestid, dtype: int64

# %%
df_lateCount["Forsinkelsestid"].plot.bar()
# Out:
# <AxesSubplot:xlabel='cat_Forsinkelse'>

# %% [markdown]
# Most of the buses are on time.

# %% [markdown]
# # 3. "Ukedag"
# Added a column that tells you which day of the week the information is taken from.

# %%
df['Dato'] = pd.to_datetime(df['Dato'])

df['Ukedag'] = df['Dato'].dt.day_name()

conditions = [
    (df['Ukedag'] == "Monday"),
    (df['Ukedag'] == "Tuesday"),
    (df['Ukedag'] == "Wednesday"),
    (df['Ukedag'] == "Thursday"),
    (df['Ukedag'] == "Friday"),
    (df['Ukedag'] == "Saturday"),
    (df['Ukedag'] == "Sunday"),
    ]

ukedagArray = ['Mandag', 'Tirsdag', 'Onsdag', 'Torsdag', 'Fredag', 'Lørdag', 'Søndag']

df['Ukedag'] = np.select(conditions, ukedagArray)
df
# Out:
#                                 TurId       Dato  Fylke    Område     Kommune  \
# 0     15006-2020-08-10T10:24:00+02:00 2020-10-08  Viken      Vest       Bærum
# 1     15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken      Vest       Bærum
# 2     15004-2020-08-03T09:54:00+02:00 2020-03-08  Viken      Vest       Bærum
# 3     15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken      Vest       Bærum
# 4     15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken      Vest       Bærum
# ...                               ...        ...    ...       ...         ...
# 5995  10001-2020-06-10T15:10:00+02:00 2020-10-06  Viken   Nordøst  Lillestrøm
# 5996  10010-2020-06-23T05:54:00+02:00 2020-06-23  Viken   Nordøst  Lillestrøm
# 5997   2007-2020-06-11T17:22:00+02:00 2020-11-06   Oslo  Indre By      Sagene
# 5998  10004-2020-08-13T04:59:00+02:00 2020-08-13   Oslo  Indre By  Gamle Oslo
# 5999  34013-2020-08-05T13:31:00+02:00 2020-05-08  Viken   Nordøst  Lillestrøm
#
#                               Holdeplass_Fra  \
# 0                                Nordliveien
# 1                           Nadderud stadion
# 2                           Ringstabekkveien
# 3                                  Gruvemyra
# 4              Lysaker stasjon (Plattform A)
# ...                                      ...
# 5995                          Brauterkrysset
# 5996                              Vestbygata
# 5997      Torshovparken  (mot Torshovparken)
# 5998  Harald Hårdrådes plass  (mot Grønland)
# 5999                                Tandberg
#
#                             Holdeplass_Til Linjetype Linjefylke Linjenavn  \
# 0                                Tjernsmyr     Lokal      Viken       150
# 1     Bekkestua bussterminal (Plattform C)     Lokal      Viken       150
# 2                                  Skallum     Lokal      Viken       150
# 3                                 Gullhaug     Lokal      Viken       150
# 4                                Tjernsmyr     Lokal      Viken       150
# ...                                    ...       ...        ...       ...
# 5995                          Nordsnoveien     Lokal      Viken       100
# 5996                        Bjørnsons gate     Lokal      Viken       100
# 5997             Torshov  (mot Bentsebrua)     Lokal       Oslo        20
# 5998             Oslo gate  (mot Grønland)     Lokal      Viken       100
# 5999                                Selmer     Lokal      Viken       340
#
#       Linjeretning Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                0                      2021-09-27 10:53:53
# 1                0                      2021-09-27 13:12:20
# 2                0                      2021-09-27 10:18:56
# 3                1                      2021-09-27 13:52:04
# 4                1                      2021-09-27 07:34:13
# ...            ...                                      ...
# 5995             1                      2021-09-27 16:23:18
# 5996             0                      2021-09-27 06:00:32
# 5997             1                      2021-09-27 17:42:43
# 5998             0                      2021-09-27 06:00:11
# 5999             1                      2021-09-27 13:52:44
#
#      Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                        2021-09-27 10:53:59
# 1                        2021-09-27 13:12:26
# 2                        2021-09-27 10:19:21
# 3                        2021-09-27 13:52:26
# 4                        2021-09-27 07:34:53
# ...                                      ...
# 5995                     2021-09-27 16:23:48
# 5996                     2021-09-27 06:00:40
# 5997                     2021-09-27 17:43:10
# 5998                     2021-09-27 06:00:23
# 5999                     2021-09-27 13:52:48
#
#      Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                          2021-09-27 10:53:00
# 1                          2021-09-27 13:12:00
# 2                          2021-09-27 10:19:00
# 3                          2021-09-27 13:51:00
# 4                          2021-09-27 07:33:00
# ...                                        ...
# 5995                       2021-09-27 16:10:00
# 5996                       2021-09-27 05:59:00
# 5997                       2021-09-27 17:32:00
# 5998                       2021-09-27 05:59:00
# 5999                       2021-09-27 13:50:00
#
#      Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                         2021-09-27 10:53:00                 112
# 1                         2021-09-27 13:12:00                 112
# 2                         2021-09-27 10:19:00                 112
# 3                         2021-09-27 13:51:00                 112
# 4                         2021-09-27 07:33:00                 112
# ...                                       ...                 ...
# 5995                      2021-09-27 16:10:00                 151
# 5996                      2021-09-27 05:59:00                 151
# 5997                      2021-09-27 17:32:00                 106
# 5998                      2021-09-27 05:59:00                 151
# 5999                      2021-09-27 13:50:00                 105
#
#       Passasjerer_Ombord Forsinkelsestid  cat_Forsinkelse   Ukedag
# 0                      5 0 days 00:00:59                2  Torsdag
# 1                      5 0 days 00:00:26                2   Lørdag
# 2                      6 0 days 00:00:21                2   Søndag
# 3                     10 0 days 00:01:26                2   Mandag
# 4                     10 0 days 00:01:53                2  Torsdag
# ...                  ...             ...              ...      ...
# 5995                   2 0 days 00:13:48                4  Tirsdag
# 5996                   2 0 days 00:01:40                2  Tirsdag
# 5997                   3 0 days 00:11:10                4   Fredag
# 5998                   5 0 days 00:01:23                2  Torsdag
# 5999                   0 0 days 00:02:48                3   Fredag
#
# [6000 rows x 20 columns]

# %% [markdown]
# Creation of a table that shows how many passengers that have traveled each day of the week.
# The statistics of how the total amount of passengers are distributed throughout the week are shown further down.

# %%
mandag=  df[df['Ukedag'].str.contains("Mandag")].Passasjerer_Ombord.sum()
tirsdag= df[df['Ukedag'].str.contains("Tirsdag")].Passasjerer_Ombord.sum()
onsdag= df[df['Ukedag'].str.contains("Onsdag")].Passasjerer_Ombord.sum()
torsdag= df[df['Ukedag'].str.contains("Torsdag")].Passasjerer_Ombord.sum()
fredag= df[df['Ukedag'].str.contains("Fredag")].Passasjerer_Ombord.sum()
lørdag= df[df['Ukedag'].str.contains("Lørdag")].Passasjerer_Ombord.sum()
søndag = df[df['Ukedag'].str.contains("Søndag")].Passasjerer_Ombord.sum()
Antall_PassasjererIUke = {'Ukedag': ["Mandag", "Tirsdag", "Onsdag", "Torsdag", "Fredag", 'Lørdag','Søndag'],
        'Passasjerer_Per_Ukedag': [mandag, tirsdag, onsdag, torsdag, fredag, lørdag, søndag]
       }

Antall_PassasjererIUkedf = pd.DataFrame(Antall_PassasjererIUke , columns = ['Ukedag', 'Passasjerer_Per_Ukedag'])
Antall_PassasjererIUkedf
# Out:
#     Ukedag  Passasjerer_Per_Ukedag
# 0   Mandag                    4692
# 1  Tirsdag                    4744
# 2   Onsdag                    4228
# 3  Torsdag                    4499
# 4   Fredag                    5110
# 5   Lørdag                    3468
# 6   Søndag                    3130

# %%
Antall_PassasjererIUkedf = pd.DataFrame(Antall_PassasjererIUkedf,columns=['Ukedag','Passasjerer_Per_Ukedag'])
Antall_PassasjererIUkedf.plot(x ='Ukedag', y='Passasjerer_Per_Ukedag', kind = 'bar')
plt.show()

# %% [markdown]
# # 4. "Måned" - specifying which month the travel took place

# %% [markdown]
# Both day of the week and which month the travel took place can be seen in the columns for arrival and departure (planned and actual), and in "TurID". Nevertheless, we chose to put it in its own columns. This makes it easier to make statistics based on both month and day of the week.

# %%
# Converting to datetime

df['Dato'] = pd.to_datetime(df['Dato'])
df['Måned'] = df['Dato'].dt.month_name()


conditions = [
    (df['Måned'] == "January"),
    (df['Måned'] == "February"),
    (df['Måned'] == "March"),
    (df['Måned'] == "April"),
    (df['Måned'] == "May"),
    (df['Måned'] == "June"),
    (df['Måned'] == "July"),
    (df['Måned'] == "August"),
    (df['Måned'] == "September"),
    (df['Måned'] == "October"),
    (df['Måned'] == "November"),
    (df['Måned'] == "December")
    ]

månedArray = ['Januar', 'Februar', 'Mars', 'April', 'Mai', 'Juni', 'Juli','August', 'September', 'Oktober','November', 'December']

df['Måned'] = np.select(conditions, månedArray).astype(str)

df
# Out:
#                                 TurId       Dato  Fylke    Område     Kommune  \
# 0     15006-2020-08-10T10:24:00+02:00 2020-10-08  Viken      Vest       Bærum
# 1     15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken      Vest       Bærum
# 2     15004-2020-08-03T09:54:00+02:00 2020-03-08  Viken      Vest       Bærum
# 3     15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken      Vest       Bærum
# 4     15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken      Vest       Bærum
# ...                               ...        ...    ...       ...         ...
# 5995  10001-2020-06-10T15:10:00+02:00 2020-10-06  Viken   Nordøst  Lillestrøm
# 5996  10010-2020-06-23T05:54:00+02:00 2020-06-23  Viken   Nordøst  Lillestrøm
# 5997   2007-2020-06-11T17:22:00+02:00 2020-11-06   Oslo  Indre By      Sagene
# 5998  10004-2020-08-13T04:59:00+02:00 2020-08-13   Oslo  Indre By  Gamle Oslo
# 5999  34013-2020-08-05T13:31:00+02:00 2020-05-08  Viken   Nordøst  Lillestrøm
#
#                               Holdeplass_Fra  \
# 0                                Nordliveien
# 1                           Nadderud stadion
# 2                           Ringstabekkveien
# 3                                  Gruvemyra
# 4              Lysaker stasjon (Plattform A)
# ...                                      ...
# 5995                          Brauterkrysset
# 5996                              Vestbygata
# 5997      Torshovparken  (mot Torshovparken)
# 5998  Harald Hårdrådes plass  (mot Grønland)
# 5999                                Tandberg
#
# 5998                   5  0 days 00:01:23               2  Torsdag    August
# 5999                   0  0 days 00:02:48               3   Fredag       Mai
#
# [6000 rows x 21 columns]

# %%
januar=  df[df['Måned'].str.contains("Januar")].Passasjerer_Ombord.sum()
februar= df[df['Måned'].str.contains("Februar")].Passasjerer_Ombord.sum()
mars= df[df['Måned'].str.contains("Mars")].Passasjerer_Ombord.sum()
april= df[df['Måned'].str.contains("April")].Passasjerer_Ombord.sum()
mai= df[df['Måned'].str.contains("Mai")].Passasjerer_Ombord.sum()
juni= df[df['Måned'].str.contains("Juni")].Passasjerer_Ombord.sum()
juli= df[df['Måned'].str.contains("Juli")].Passasjerer_Ombord.sum()
august=  df[df['Måned'].str.contains("August")].Passasjerer_Ombord.sum()
september= df[df['Måned'].str.contains("September")].Passasjerer_Ombord.sum()
oktober= df[df['Måned'].str.contains("Oktober")].Passasjerer_Ombord.sum()
november = df[df['Måned'].str.contains("November")].Passasjerer_Ombord.sum()
desember=  df[df['Måned'].str.contains("December")].Passasjerer_Ombord.sum()

Antall_Passasjerer = {'Måned': ["Januar", "Februar", "Mars", "April", "Mai", 'Juni','Juli','August',"September", "Oktober" , "November","December"],
        'Passasjerer_Per_Måned': [januar,februar, mars, april, mai, juni, juli, august, september, oktober,november, desember]
       }


Passasjerer_Per_Måneddf = pd.DataFrame(Antall_Passasjerer , columns = ['Måned', 'Passasjerer_Per_Måned'])
Passasjerer_Per_Måneddf
# Out:
#         Måned  Passasjerer_Per_Måned
# 0      Januar                    792
# 1     Februar                    821
# 2        Mars                   1082
# 3       April                    813
# 4         Mai                    911
# 5        Juni                   5738
# 6        Juli                   7007
# 7      August                   8803
# 8   September                    901
# 9     Oktober                    979
# 10   November                   1107
# 11   December                    917

# %% [markdown]
# Creating a plot that shows the statistics regarding most passengers that travelled the different months.

# %%
Passasjerer_Per_Måned = pd.DataFrame(Antall_Passasjerer,columns=['Måned','Passasjerer_Per_Måned'])
Passasjerer_Per_Måned.plot(x ='Måned', y='Passasjerer_Per_Måned', kind = 'bar')
plt.show()

# %% [markdown]
# # 5. "PlassPåBussen" - what is the current capacity (spots left on the bus)
# We create a new column called "PlassPåBussen". This shows how many slots that are left on the bus after comparing total capacity and spots that are already taken

# %%
# Creating a column called "PlassPåBussen"
# Shows how many slots that are left after comparing total capacity and spots taken on the bus

df['PlassPåBussen'] =  df['Passasjerer_Ombord'] > df['Kjøretøy_Kapasitet']

if True:
    df['PlassPåBussen'] = (df['Kjøretøy_Kapasitet'] - df['Passasjerer_Ombord']).astype(str)+" plasser igjen"
else:
     "0 plass igjen"

df.sample(30)
# Out:
#                                 TurId       Dato  Fylke    Område  \
# 692    6002-2020-07-11T10:40:00+02:00 2020-11-07   Oslo   Nordøst
# 2622   4005-2020-08-24T19:48:00+02:00 2020-08-24   Oslo      Vest
# 4121  40009-2020-07-28T07:22:00+02:00 2020-07-28  Viken   Nordøst
# 5760  14007-2020-07-15T07:25:00+02:00 2020-07-15  Viken      Vest
# 851     Lillestrøm                                      Nannestadgata
# 2669    Gamle Oslo                           Ladegården (mot sentrum)
# 146     Lillestrøm                                            Veibrån
# 2886     Nannestad                                      Skjennum gård
# 5919    Lillestrøm                                     Strømmen kirke
# 5288   Grünerløkka       Heimdalsgata (buss for trikk i Heimdalsgata)
# 457       Rælingen                                         Grinitajet
# 3345  Nordre Follo                                              Fjell
# 2674    Gamle Oslo                         Vålerenga  (mot Galgeberg)
# 4341    Ullensaker                                       Vilbergvegen
# 2566         Bærum                        Langoddveien  (mot Snarøya)
# 4115    Lillestrøm                        Skedsmokorset (Plattform 1)
# 4286     Lørenskog                            Knatten (Solheimsveien)
# 3369    Lillestrøm                                     Sagdalen skole
#
#                                  Holdeplass_Til Linjetype Linjefylke  \
# 692             Linne hotell  (mot Økernbråten)     Lokal       Oslo
# 2622                  Orebakken  (mot Hovseter)     Lokal       Oslo
# 4121                Skedsmokorset (Plattform 1)  Ekspress      Viken
# 5760       Bekkestua bussterminal (Plattform B)     Lokal      Viken
# 2746  Sinsenkrysset  (fra Aker sykehus) (plf F)     Lokal      Viken
# 5249                                Glenneveien     Lokal      Viken
# 4443                             St. Olavs gate     Lokal      Viken
# 4600                              Kveldsroveien     Lokal      Viken
# 5640              Linderudsletta  (mot Brobekk)     Lokal      Viken
# 1707                                    Landøya     Lokal      Viken
# 409                                    Nordkisa     Lokal      Viken
# 1903             Nydalen T  (mot Sandakerveien)     Lokal       Oslo
# 5585                                    Skjæret     Lokal      Viken
# 4093                Ekeberghallen  (mot Holtet)     Lokal       Oslo
# 1098                                       Jong     Lokal      Viken
# 3484     Vækerø  (E18 på nordsiden mot Lysaker)     Lokal      Viken
# 851                                  Vestbygata     Lokal      Viken
# 2669                   Bjørvika (buss mot vest)     Lokal      Viken
# 146                          Lund i Brånåsdalen     Lokal      Viken
# 2886                                Bjørke gård     Lokal      Viken
# 5919                        Strømmen storsenter     Lokal      Viken
# 5288                Herslebs gate (fra sentrum)     Lokal       Oslo
# 457                                        Jahr     Lokal      Viken
# 3345                                    Rolborg     Lokal      Viken
# 2674                 Galgeberg  (fra Etterstad)     Lokal      Viken
# 4341                                 Gravhaugen     Lokal      Viken
# 2566                      Halden  (mot Snarøya)     Lokal       Oslo
# 4115                                   Elgfaret     Lokal      Viken
# 4286                         Dovre trygdesenter     Lokal      Viken
# 3369                            Frydenlundsgata     Lokal      Viken
#
#      Linjenavn  ...  Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 692         60  ...                      2021-09-27 10:44:24
# 2622        46  ...                      2021-09-27 20:03:47
# 4121      400E  ...                      2021-09-27 07:50:03
# 5760       145  ...                      2021-09-27 07:47:06
# 2746       390  ...                      2021-09-27 18:54:14
# 5249       110  ...                      2021-09-27 08:27:02
# 4443       480  ...                      2021-09-27 14:35:51
# 4600       270  ...                      2021-09-27 06:38:53
# 5640       380  ...                      2021-09-27 22:41:06
# 1707       250  ...                      2021-09-27 08:51:09
# 409        440  ...                      2021-09-27 20:13:20
# 1903        37  ...                      2021-09-27 07:41:05
